# %% [markdown]
# # ConvNeXt-Tiny diagnostic experiment
# Use the same manifest and development splits as EfficientNet for a fair comparison.

# %%
import pandas as pd
from src.training.experiment_runner import load_config
from src.strategies.convnext_strategy import train
config = load_config('configs/convnext.yaml')
manifest = pd.read_csv('data/processed/manifest.csv')
result = train(manifest, config, run_name='convnext_screening')
result.as_dict()
