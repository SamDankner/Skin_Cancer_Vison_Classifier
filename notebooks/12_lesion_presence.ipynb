# %% [markdown]
# # Lesion presence experiment
# This is intentionally separate from diagnosis: lesion-present versus true normal skin. It cannot train until the manifest contains both classes.

# %%
import pandas as pd
from src.training.experiment_runner import load_config
from src.strategies.lesion_presence_strategy import train
config = load_config('configs/lesion_presence.yaml')
manifest = pd.read_csv('data/processed/manifest.csv')
result = train(manifest, config, run_name='lesion_presence_screening')
result.as_dict()
