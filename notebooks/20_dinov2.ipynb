# %% [markdown]
# # DINOv2 clinical-photo experiments
# Use a pre-split development manifest; DDI is excluded.

# %%
from src.training.experiment_runner import load_config
from src.strategies.dinov2_strategy import train_dinov2
import pandas as pd
config = load_config('configs/dinov2.yaml')
manifest = pd.read_csv('data/processed/development_manifest.csv')
result = train_dinov2(manifest, config)
result.best_checkpoint, result.best_epoch, result.metrics
