# %% [markdown]
# # EfficientNetV2-S diagnostic experiment
# Development data only; this notebook never accesses DDI.

# %%
import pandas as pd
from src.training.experiment_runner import load_config
from src.strategies.efficientnet_strategy import train
config = load_config('configs/efficientnet.yaml')
manifest = pd.read_csv('data/processed/development_manifest.csv')
result = train(manifest, config, run_name='efficientnet_screening')
result.as_dict()
