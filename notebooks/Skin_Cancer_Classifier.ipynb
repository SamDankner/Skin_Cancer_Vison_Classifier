# %%
"""
Goal is to make a model that can predict whether skin cancer
is present on a person based on an input photo, and other factors (i.e. age, weight, etc)

Due to my desire to make this highly accurate, all input images will need to be cropped, rotated, etc
in order to make the model allow for non-perfect input photos, as users would not input perfect photos
"""
# Out:
# '\nGoal is to make a model that can predict whether skin cancer\nis present on a person based on an input photo, and other factors (i.e. age, weight, etc)\n\nDue to my desire to make this highly accurate, all input images will need to be cropped, rotated, etc\n'
